# %% [markdown]
# This scritp aims to solve the Grad-Shafranov equation modelling the plasma equilibrium in an axisymmetrical (cylindrical) system.
# It shall constitute the benchmark or miniature code for the actual project behind, which goal is to develop a module for ALYA (BSC-Marenostrum)
# computing the plasma equilibrium.

# %%
import sys
sys.path.append('/home/elmanyer/Documents/BSC/MasterThesis/Code/EQUILI_PY/')

from src.DimensionlessGradShafranovCutFEM import *

### LOCATION OF FOLDERS
folder_MESHES = '/home/elmanyer/Documents/BSC/MasterThesis/Code/EQUILI_PY/MESHES/'   # MESHES
folder_CASES = '/home/elmanyer/Documents/BSC/MasterThesis/Code/EQUILI_PY/CASES/'     # CASES

### SELECT MESH FOLDER...
#MESH = 'TS-UNSTRUCTURED_ULTRACOARSE'
#MESH = 'TS-UNSTRUCTURED_COARSE'
#MESH = 'TS-UNSTRUCTURED_COARSE-FINE'
#MESH = 'TS-UNSTRUCTURED_FINE'
MESH = 'TS-UNSTRUCTURED_FINE_EXTENDED'
#MESH = 'TS-UNSTRUCTURED_ULTRAFINE'

# ... WITH MESH ELEMENTS:
ElementType = 1     # Element type -> 1: TRIANGLE  ; 2: QUADRILATERAL
ElementOrder = 1    # Element order -> 1: LINEAR  ; 2: QUADRATIC ; 3: CUBIC ...

### SELECT SOLUTION CASE FILE:
#CASE = 'TS-FIXED-1W-LINEAR'         # FIXED PLASMA BOUNDARY WITH TOKAMAK FIRST WALL PLASMA REGION SHAPE AND LINEAR PLASMA CURRENT MODEL
#CASE = 'TS-FIXED-1W-NONLINEAR'      # FIXED PLASMA BOUNDARY WITH TOKAMAK FIRST WALL PLASMA REGION SHAPE AND NONLINEAR PLASMA CURRENT MODEL
#CASE = 'TS-FIXED-F4E-LINEAR'         # FIXED PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY AND LINEAR PLASMA CURRENT
#CASE = 'TS-FIXED-F4E-PROFILES'      # FIXED PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY AND PLASMA CURRENT MODEL BASED ON PROFILES FOR PRESSURE AND TOROIDAL FIELD

#CASE = 'TS-FREE-F4E-LINEAR'          # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY AND LINEAR PLASMA CURRENT
#CASE = 'TS-FREE-F4E-NONLINEAR'       # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY AND NONLINEAR PLASMA CURRENT MODEL
CASE = 'TS-FREE-F4E-PROFILES'        # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY AND PLASMA CURRENT MODEL BASED ON PROFILES FOR PRESSURE AND TOROIDAL FIELD
#CASE = 'TS-FREE-F4E-LINEAR-1W'       # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY, LINEAR PLASMA CURRENT AND FIRST WALL VACUUM VESSEL GEOMETRY  
#CASE = 'TS-FREE-F4E-PROFILES-1W'     # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY, PLASMA CURRENT MODEL BASED ON PROFILES FOR PRESSURE AND TOROIDAL FIELD AND FIRST WALL VACUUM VESSEL GEOMETRY  

##############################################################

# DECLARE OBJECT PROBLEM 
Problem = GradShafranovCutFEM(folder_MESHES+MESH,folder_CASES+CASE,ElementType,ElementOrder)
Problem.EQUILI()
# Out:
# READ INPUT FILES...
#      -> READ MESH DATA FILES...Done!
#      -> READ EQUILI DATA FILE...Done!
# Done!
# INITIALIZATION...
#      -> ALLOCATE MEMORY...Done!
#      -> ADIMENSIONALISE PROBLEM...
#          => CHARACTERISTIC VALUES:
#              R0 =  6.0
#              Jc =  416666.6666666667
#              PHIc =  113.09733
#              Pc =  7853981.249999999
#              Gc =  18.849555
# Done!
#      -> INITIALISE LEVEL-SET...Done!
#      -> INITIALISE ELEMENTS...Done!
#      -> CLASSIFY ELEMENTS...Done!
#      -> APPROXIMATE VACUUM VESSEL FIRST WALL...Done!
#      -> APPROXIMATE PLASMA/VACUUM INTERFACE...Done!
#      -> COMPUTE NUMERICAL INTEGRATION QUADRATURES...Done!
#      -> INITIALISE UNKNOWN VECTORS AND COMPUTE INITIAL GUESS...
#          -> COMPUTE INITIAL GUESS FOR PHI_NORM...Done!
# Total plasma current normalization factor =  -516.3038159042183
# Normalised total plasma current =  -36.0
#          -> COMPUTE INITIAL VACUUM VESSEL FIRST WALL VALUES PHI_B...Done!
#      Done!
# Done!
# START ITERATION...
# OUTER ITERATION = 1 , INNER ITERATION = 1
# Total plasma current normalization factor =  1
# Normalised total plasma current =  0.06972638762499193
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [0.89401275 0.07281962]  (ELEMENT  1275 ) WITH VALUE PHI_0 =  [0.07769037]
# SADDLE POINT AT  [ 0.67939143 -0.59417901]  (ELEMENT  1694 ) WITH VALUE PHI_X =  [-2.36333092]
# OUTER ITERATION = 1 , INNER ITERATION = 2
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -8.763959824826184
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13066972 -0.07233339]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.60108468]
# SADDLE POINT AT  [ 0.67746069 -0.59493441]  (ELEMENT  1694 ) WITH VALUE PHI_X =  [-2.36798023]
# OUTER ITERATION = 1 , INNER ITERATION = 3
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -7.0342385521782695
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13155163 -0.0729647 ]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.54038535]
# SADDLE POINT AT  [ 0.67536153 -0.59466985]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37200431]
# OUTER ITERATION = 1 , INNER ITERATION = 4
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.992641704356692
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13171496 -0.07307728]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.4843627]
# SADDLE POINT AT  [ 0.67447986 -0.59481441]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37220368]
# OUTER ITERATION = 1 , INNER ITERATION = 5
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990480882781929
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13172371 -0.07308319]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.48165041]
# SADDLE POINT AT  [ 0.67446279 -0.59483551]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37216432]
# OUTER ITERATION = 1 , INNER ITERATION = 6
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.9902388379730835
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13172258 -0.07308239]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.48219557]
# SADDLE POINT AT  [ 0.67446615 -0.59483135]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37217206]
# OUTER ITERATION = 1 , INNER ITERATION = 7
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990264089895065
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.1317228  -0.07308251]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.48209181]
# SADDLE POINT AT  [ 0.67446547 -0.59483218]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37217051]
# OUTER ITERATION = 1 , INNER ITERATION = 8
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990260956982034
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13172273 -0.07308245]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.48211444]
# SADDLE POINT AT  [ 0.67446558 -0.59483204]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37217076]
# OUTER ITERATION = 1 , INNER ITERATION = 9
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990264032245143
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13172272 -0.07308241]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.48211393]
# SADDLE POINT AT  [ 0.67446555 -0.59483208]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37217069]
# Total plasma current normalization factor =  5.150018611151904
# Normalised total plasma current =  -36.0
# COMPUTE VACUUM VESSEL FIRST WALL VALUES PHI_B...OUTER ITERATION = 2 , INNER ITERATION = 1
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990266000601478
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13167427 -0.07305362]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.50674262]
# SADDLE POINT AT  [ 0.67422634 -0.59516151]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37158726]
# OUTER ITERATION = 2 , INNER ITERATION = 2
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.989549079238864
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13165442 -0.07303994]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.51473429]
# SADDLE POINT AT  [ 0.67427708 -0.59509729]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37169689]
# OUTER ITERATION = 2 , INNER ITERATION = 3
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.990000284411062
#      Integrate over non-cut elements...Done!
#      Integrate over cut-elements subelements...Done!
#      Integrate along cut-elements interface edges...Done!
# ERROR IN LOCAL EXTREMUM HESSIAN
# LOCAL EXTREMUM AT  [ 1.13165776 -0.07304223]  (ELEMENT  3335 ) WITH VALUE PHI_0 =  [-0.51322866]
# SADDLE POINT AT  [ 0.6742675 -0.5951094]  (ELEMENT  1759 ) WITH VALUE PHI_X =  [-2.37167604]
# OUTER ITERATION = 2 , INNER ITERATION = 4
# Total plasma current normalization factor =  1
# Normalised total plasma current =  -6.989932075287242
#      Integrate over non-cut elements...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 38
#      31 #CASE = 'TS-FREE-F4E-LINEAR-1W'       # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY, LINEAR PLASMA CURRENT AND FIRST WALL VACUUM VESSEL GEOMETRY
#      32 #CASE = 'TS-FREE-F4E-PROFILES-1W'     # FREE PLASMA BOUNDARY WITH F4E PLASMA REGION GEOMETRY, PLASMA CURRENT MODEL BASED ON PROFILES FOR PRESSURE AND TOROIDAL FIELD AND FIRST WALL VACUUM VESSEL GEOMETRY
#      33
#      34 ##############################################################
#      35
#      36 # DECLARE OBJECT PROBLEM
#      37 Problem = GradShafranovCutFEM(folder_MESHES+MESH,folder_CASES+CASE,ElementType,ElementOrder)
# ---> 38 Problem.EQUILI()
#
# File ~/Documents/BSC/MasterThesis/Code/EQUILI_PY/src/DimensionlessGradShafranovCutFEM.py:1715, in GradShafranovCutFEM.EQUILI(self)
#    1713 #self.PlotPROFILES()
#    1714 self.PlotJphi_JphiNORM()
# -> 1715 self.AssembleGlobalSystem()
#    1716 self.SolveSystem()                          # 1. SOLVE CutFEM SYSTEM  ->> PHI
#    1717 self.ComputeCriticalPHI(self.PHI)           # 2. COMPUTE CRITICAL VALUES   PHI_0 AND PHI_X
#
# File ~/Documents/BSC/MasterThesis/Code/EQUILI_PY/src/DimensionlessGradShafranovCutFEM.py:1605, in GradShafranovCutFEM.AssembleGlobalSystem(self)
#    1603             SourceTermg[ig] = ELEMENT.Xg2D[ig,0]*self.Jphi(ELEMENT.Xg2D[ig,0],ELEMENT.Xg2D[ig,1],PHIg[ig])*self.gamma
#    1604     # COMPUTE ELEMENTAL MATRICES
# -> 1605     ELEMENT.IntegrateElementalDomainTerms(SourceTermg,self.LHS,self.RHS)
#    1606 print("Done!")
#    1608 # INTEGRATE OVER THE SURFACES OF SUBELEMENTS IN ELEMENTS CUT BY INTERFACES (MODIFIED QUADRATURES)
#
# File ~/Documents/BSC/MasterThesis/Code/EQUILI_PY/src/ElementObject.py:650, in Element.IntegrateElementalDomainTerms(self, SourceTermg, LHS, RHS)
#     646 for i in range(self.n):   # ROWS ELEMENTAL MATRIX
#     647     for j in range(self.n):   # COLUMNS ELEMENTAL MATRIX
#     648         # COMPUTE LHS MATRIX TERMS
#     649         ### STIFFNESS TERM  [ nabla(N_i)*nabla(N_j) *(Jacobiano*2pi*rad) ]
# --> 650         LHS[self.Te[i],self.Te[j]] -= np.transpose((self.invJg[ig,:,:]@Ngrad[:,i]))@(self.invJg[ig,:,:]@Ngrad[:,j])*self.detJg[ig]*self.Wg2D[ig]
#     651         ### GRADIENT TERM (ASYMMETRIC)  [ (1/R)*N_i*dNdr_j *(Jacobiano*2pi*rad) ]  ONLY RESPECT TO R
#     652         LHS[self.Te[i],self.Te[j]] -= (1/self.Xg2D[ig,0])*self.N[ig,j] * (self.invJg[ig,0,:]@Ngrad[:,i])*self.detJg[ig]*self.Wg2D[ig]
#
# File <__array_function__ internals>:180, in transpose(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:660, in transpose(a, axes)
#     601 @array_function_dispatch(_transpose_dispatcher)
#     602 def transpose(a, axes=None):
#     603     """
#     604     Reverse or permute the axes of an array; returns the modified array.
#     605
#    (...)
#     658
#     659     """
# --> 660     return _wrapfunc(a, 'transpose', axes)
#
# KeyboardInterrupt:

# %%
Problem.PlotSolution(Problem.PHI)

# %%
self = Problem
phi = self.PHI

if len(np.shape(phi)) == 2:
    phi = phi[:,0]
fig, axs = plt.subplots(1, 1, figsize=(7,8))
axs.set_xlim(self.Xmin,self.Xmax)
axs.set_ylim(self.Ymin,self.Ymax)
a = axs.tricontourf(self.Xstar[:,0],self.Xstar[:,1], phi, levels=np.linspace(0, 1, 30))
axs.tricontour(self.Xstar[:,0],self.Xstar[:,1], self.PlasmaBoundLevSet, levels=[0], colors = 'red')
axs.tricontour(self.Xstar[:,0],self.Xstar[:,1], phi, levels=[0], colors = 'black')
plt.colorbar(a, ax=axs)
plt.show()

# %%
self = Problem
phi = self.PHI_NORM[:,0]

if len(np.shape(phi)) == 2:
    phi = phi[:,0]
fig, axs = plt.subplots(1, 1, figsize=(7,8))
axs.set_xlim(self.Xmin,self.Xmax)
axs.set_ylim(self.Ymin,self.Ymax)
a = axs.tricontourf(self.X[:,0],self.X[:,1], phi, levels=30)
axs.tricontour(self.X[:,0],self.X[:,1], self.PlasmaBoundLevSet, levels=[0], colors = 'red')
contour = axs.tricontour(self.X[:,0],self.X[:,1], phi, levels=[0], colors = 'black')
plt.colorbar(a, ax=axs)
## PLOT LOCATION OF CRITICAL POINTS 
# LOCAL EXTREMUM
axs.scatter(self.Xcrit[0,0],self.Xcrit[0,1],marker = 'x',color='red', s = 40, linewidths = 2)
# SADDLE POINT
axs.scatter(self.Xcrit[1,0],self.Xcrit[1,1],marker = 'x',color='green', s = 40, linewidths = 2)
plt.show()

# %%
contour_lines = contour.collections
print(contour_lines)
# Out:
# <a list of 1 PathCollection objects>

# %%
self = Problem

self.ComputeTotalPlasmaCurrentCorrectionFactor()
print(self.gamma)

Tcurrent = 0
# INTEGRATE OVER PLASMA ELEMENTS
for elem in self.PlasmaElems:
    # ISOLATE ELEMENT
    ELEMENT = self.Elements[elem]
    # MAPP GAUSS NODAL PHI VALUES FROM REFERENCE ELEMENT TO PHYSICAL SUBELEMENT
    PHIg = ELEMENT.N @ self.PHI_NORM[ELEMENT.Te,0]
    # LOOP OVER GAUSS NODES
    for ig in range(ELEMENT.Ng2D):
        # LOOP OVER ELEMENTAL NODES
        for i in range(ELEMENT.n):
            Tcurrent += self.Jphi(ELEMENT.Xg2D[ig,0],ELEMENT.Xg2D[ig,1],PHIg[ig])*ELEMENT.N[ig,i]*ELEMENT.detJg[ig]*ELEMENT.Wg2D[ig]*self.gamma
            
# INTEGRATE OVER INTERFACE ELEMENTS, FOR SUBELEMENTS INSIDE PLASMA REGION
for elem in self.PlasmaBoundElems:
    # ISOLATE ELEMENT
    ELEMENT = self.Elements[elem]
    # LOOP OVER SUBELEMENTS
    for SUBELEM in ELEMENT.SubElements:
        # INTEGRATE IN SUBDOMAIN INSIDE PLASMA REGION
        if SUBELEM.Dom < 0:
            # MAPP GAUSS NODAL PHI VALUES FROM REFERENCE ELEMENT TO PHYSICAL SUBELEMENT
            PHIg = SUBELEM.N @ self.PHI_NORM[ELEMENT.Te,0]
            # LOOP OVER GAUSS NODES
            for ig in range(SUBELEM.Ng2D):
                # LOOP OVER ELEMENTAL NODES
                for i in range(SUBELEM.n):
                    Tcurrent += self.Jphi(SUBELEM.Xg2D[ig,0],SUBELEM.Xg2D[ig,1],PHIg[ig])*SUBELEM.N[ig,i]*SUBELEM.detJg[ig]*SUBELEM.Wg2D[ig]*self.gamma
                    
print(Tcurrent)

#print(Tcurrent*self.gamma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 3
#       1 self = Problem
# ----> 3 self.ComputeTotalPlasmaCurrentCorrectionFactor()
#       4 print(self.gamma)
#       6 Tcurrent = 0
#
# AttributeError: 'GradShafranovCutFEM' object has no attribute 'ComputeTotalPlasmaCurrentCorrectionFactor'

# %%
def ComputePHI_B(self,PHI):
        
        """ FUNCTION TO COMPUTE THE COMPUTATIONAL DOMAIN BOUNDARY VALUES FOR PHI, PHI_B, ON BOUNDARY ELEMENT. 
        THESE MUST BE TREATED AS NATURAL BOUNDARY CONDITIONS (DIRICHLET BOUNDARY CONDITIONS).
        FOR 'FREE' BOUNDARY PROBLEM, SUCH VALUES ARE OBTAINED BY ACCOUNTING FOR THE CONTRIBUTIONS FROM THE EXTERNAL
        FIXED COILS AND THE CONTRIBUTION FROM THE PLASMA CURRENT ITSELF, FOR WHICH WE 
        INTEGRATE THE PLASMA'S GREEN FUNCTION."""
        
        def ellipticK(k):
            """ COMPLETE ELLIPTIC INTEGRAL OF 1rst KIND """
            pk=1.0-k*k
            if k == 1:
                ellipticK=1.0e+16
            else:
                AK = (((0.01451196212*pk+0.03742563713)*pk +0.03590092383)*pk+0.09666344259)*pk+1.38629436112
                BK = (((0.00441787012*pk+0.03328355346)*pk+0.06880248576)*pk+0.12498593597)*pk+0.5
                ellipticK = AK-BK*np.log(pk)
            return ellipticK

        def ellipticE(k):
            """COMPLETE ELLIPTIC INTEGRAL OF 2nd KIND"""
            pk = 1 - k*k
            if k == 1:
                ellipticE = 1
            else:
                AE=(((0.01736506451*pk+0.04757383546)*pk+0.0626060122)*pk+0.44325141463)*pk+1
                BE=(((0.00526449639*pk+0.04069697526)*pk+0.09200180037)*pk+0.2499836831)*pk
                ellipticE = AE-BE*np.log(pk)
            return ellipticE
        
        def GreenFunction(Xb,Xp):
            """ GREEN FUNCTION CORRESPONDING TO THE TOROIDAL ELLIPTIC OPERATOR """
            k = np.sqrt(4*Xb[0]*Xp[0]/((Xb[0]+Xp[0])**2 + (Xp[1]-Xb[1])**2))
            Greenfun = (1/(2*np.pi))*(np.sqrt(Xp[0]*Xb[0])/k)*((2-k**2)*ellipticK(k)-2*ellipticE(k))
            return Greenfun
        
        """ RELEVANT ATTRIBUTES:
                # Nbound: NUMBER OF COMPUTATIONAL DOMAIN'S BOUNDARIES (NUMBER OF ELEMENTAL EDGES)
                # Nnbound: NUMBER OF NODES ON COMPUTATIONAL DOMAIN'S BOUNDARY
                # BoundaryNodes: LIST OF NODES (GLOBAL INDEXES) ON THE COMPUTATIONAL DOMAIN'S BOUNDARY
                # Tbound: MESH BOUNDARIES CONNECTIVITY MATRIX  (LAST COLUMN YIELDS THE ELEMENT INDEX OF THE CORRESPONDING BOUNDARY EDGE)
                # Ncoils: TOTAL NUMBER OF COILS
                # Xcoils: COILS' COORDINATE MATRIX 
                # Icoils: COILS' CURRENT
                # Nsolenoids: TOTAL NUMBER OF SOLENOIDS
                # Xsolenoids: SOLENOIDS' COORDINATE MATRIX
                # Nturnssole: SOLENOIDS' NUMBER OF TURNS
                # Isolenoids: SOLENOIDS' CURRENT"""
                
        PHI_B = np.zeros([self.NnFW])    
        # FOR FIXED PLASMA BOUNDARY PROBLEM THE VACUUM VESSEL BOUNDARY VALUES PHI_B ARE IRRELEVANT ->> PHI_B = 0
    
        if self.PLASMA_BOUNDARY == 'FREE':
            k = 0
            # COMPUTE PHI_B VALUE ON EACH VACUUM VESSEL ELEMENT FIRST WALL INTERFACE INTEGRATION POINTS
            for element in self.VacVessWallElems:
                for edge in range(self.Elements[element].Neint):
                    for point in range(self.Elements[element].Ng1D):
                        # ISOLATE NODAL COORDINATES
                        Xnode = self.Elements[element].Xeint[edge,point,:]
        
                        # CONTRIBUTION FROM EXTERNAL COILS CURRENT 
                        for icoil in range(self.Ncoils): 
                            PHI_B[k] += self.mu0 * GreenFunction(Xnode,self.Xcoils[icoil,:]) * self.Icoils[icoil]
                
                        # CONTRIBUTION FROM EXTERNAL SOLENOIDS CURRENT  ->>  INTEGRATE OVER SOLENOID LENGTH 
                        for isole in range(self.Nsolenoids):
                            Xsole = np.array([[self.Xsolenoids[isole,0], self.Xsolenoids[isole,1]],[self.Xsolenoids[isole,0], self.Xsolenoids[isole,2]]])   # COORDINATES OF SOLENOID EDGES
                            Jsole = self.Isolenoids[isole]/np.linalg.norm(Xsole[0,:]-Xsole[1,:])   # SOLENOID CURRENT LINEAR DENSITY
                            # LOOP OVER GAUSS NODES
                            for ig in range(self.Ng1D):
                                # MAPP 1D REFERENCE INTEGRATION GAUSS NODES TO PHYSICAL SPACE ON SOLENOID
                                Xgsole = self.N1D[ig,:] @ Xsole
                                # COMPUTE DETERMINANT OF JACOBIAN OF TRANSFORMATION FROM 1D REFERENCE ELEMENT TO 2D PHYSICAL SOLENOID 
                                detJ1D = Jacobian1D(Xsole[0,:],Xsole[1,:],self.dNdxi1D[ig,:])
                                detJ1D = detJ1D*2*np.pi*np.mean(Xsole[:,0])
                                for l in range(self.nsole):
                                    PHI_B[k] += self.mu0 * GreenFunction(Xnode,Xgsole) * Jsole * self.N1D[ig,l] * detJ1D * self.Wg1D[ig]
                        
                        # CONTRIBUTION FROM PLASMA CURRENT  ->>  INTEGRATE OVER PLASMA REGION
                        #   1. INTEGRATE IN PLASMA ELEMENTS
                        for elem in self.PlasmaElems:
                            # ISOLATE ELEMENT OBJECT
                            ELEMENT = self.Elements[elem]
                            # INTERPOLATE ELEMENTAL PHI ON PHYSICAL GAUSS NODES
                            PHIg = ELEMENT.N @ PHI[ELEMENT.Te]
                            # LOOP OVER GAUSS NODES
                            for ig in range(ELEMENT.Ng2D):
                                for l in range(ELEMENT.n):
                                    PHI_B[k] += self.mu0 * GreenFunction(Xnode, ELEMENT.Xg2D[ig,:])*self.Jphi(ELEMENT.Xg2D[ig,0],ELEMENT.Xg2D[ig,1],
                                                                            PHIg[ig])*ELEMENT.N[ig,l]*ELEMENT.detJg[ig]*ELEMENT.Wg2D[ig]*self.gamma
                            
                        #   2. INTEGRATE IN CUT ELEMENTS, OVER SUBELEMENT IN PLASMA REGION
                        for elem in self.PlasmaBoundElems:
                            # ISOLATE ELEMENT OBJECT
                            ELEMENT = self.Elements[elem]
                            # INTEGRATE ON SUBELEMENT INSIDE PLASMA REGION
                            for SUBELEM in ELEMENT.SubElements:
                                if SUBELEM.Dom < 0:  # IN PLASMA REGION
                                    # INTERPOLATE ELEMENTAL PHI ON PHYSICAL GAUSS NODES
                                    PHIg = SUBELEM.N @ PHI[ELEMENT.Te]
                                    # LOOP OVER GAUSS NODES
                                    for ig in range(SUBELEM.Ng2D):
                                        for l in range(SUBELEM.n):
                                            PHI_B[k] += self.mu0 * GreenFunction(Xnode, SUBELEM.Xg2D[ig,:])*self.Jphi(SUBELEM.Xg2D[ig,0],SUBELEM.Xg2D[ig,1],
                                                                    PHIg[ig])*SUBELEM.N[ig,l]*SUBELEM.detJg[ig]*SUBELEM.Wg2D[ig]*self.gamma
                                           
                        k += 1
        return PHI_B

self = Problem
PHI = self.PHI_NORM[:,0].copy()
#PHI = -0.05*PHI
PHI_B = ComputePHI_B(self,PHI)


import matplotlib as mpl
# COLLECT PHI_g DATA ON VACUUM VESSEL FIRST WALL  
X_Bg = np.zeros([self.NnFW,self.dim])
k = 0
for elem in self.VacVessWallElems:
    for edge in range(self.Elements[elem].Neint):
        for point in range(self.Elements[elem].Ng1D):
            X_Bg[k,:] = self.Elements[elem].Xgint[edge,point]
            k += 1
    
fig, axs = plt.subplots(1, 2, figsize=(14,7))
# LEFT SUBPLOT: VALUES FOR PHI_NORM
axs[0].set_aspect('equal')
axs[0].set_ylim(self.Ymin-0.5,self.Ymax+0.5)
axs[0].set_xlim(self.Xmin-0.5,self.Xmax+0.5)
a = axs[0].tricontourf(self.X[:,0],self.X[:,1], PHI, levels=30)
axs[0].tricontour(self.X[:,0],self.X[:,1], self.PlasmaBoundLevSet, levels=[0], colors = 'red')
axs[0].tricontour(self.X[:,0],self.X[:,1], PHI, levels=[0], colors = 'black')
plt.colorbar(a, ax=axs[0])

# RIGHT SUBPLOT: COMPUTED VALUES FOR PHI_B
axs[1].set_aspect('equal')
axs[1].set_ylim(self.Ymin-0.5,self.Ymax+0.5)
axs[1].set_xlim(self.Xmin-0.5,self.Xmax+0.5)
norm = plt.Normalize(PHI_B.min(),PHI_B.max())
cmap = plt.get_cmap('viridis')
linecolors_Bg = cmap(norm(PHI_B))
axs[1].scatter(X_Bg[:,0],X_Bg[:,1],color = linecolors_Bg)
fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),ax=axs[1])

plt.show()

# %%
# VERIFY D-SHAPE PARAMETRISATION 

Xstar = self.X/self.R0
Dshape0 = np.zeros([self.Nn])
for i in range(self.Nn):
    Dshape0[i] = (Xstar[i,0]**4)/8 + self.coeffs1W[0] + self.coeffs1W[1]*Xstar[i,0]**2 + self.coeffs1W[2]*(Xstar[i,0]**4-4*Xstar[i,0]**2*Xstar[i,1]**2)

n = 360
theta = np.linspace(0,2*np.pi,n)
xb = np.zeros([n])
yb = np.zeros([n])
alpha = np.arcsin(self.delta)
for i in range(n):
    xb[i] = 1+self.epsilon*np.cos(theta[i]+alpha*np.sin(theta[i]))
    yb[i] = self.epsilon*self.kappa*np.sin(theta[i])

fig, axs = plt.subplots(1, 1, figsize=(6,6))
axs.tricontour(Xstar[:,0],Xstar[:,1],Dshape0,levels=[0])
axs.plot(xb,yb)
plt.plot()
# Out:
# []
